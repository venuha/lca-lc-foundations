# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='29efdb3a-3950-4d85-8486-f9e96c846368'),
#               AIMessage(content="Hi Seán! Nice to meet you. Green is a great color—calming and lively. What would you like to do today? Here are a few ideas:\n- Learn fun facts about the color green\n- Create a green-themed color palette for a project\n- Write something (poem, short story) inspired by green\n- If you’d like, practice Irish phrases or chat about Irish culture\n\nTell me what you're in the mood for, or ask me anything.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1131, 'prompt_tokens': 18, 'total_tokens': 1149, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1024, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D3y8Au0wzpOYRDvWQaBzkPdas4yYU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c1298-425b-7493-9749-01b15b81de41-0', usage_metadata={'input_tokens': 18, 'output_tokens': 1131, 'total_tokens': 1149, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1024}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='3b20c3aa-61e2-432d-9fcd-e78a7f7c5025'),
#               AIMessage(content='I don’t know your favourite colour yet. Want me to guess or help you figure it out?\n\n- If you want to guess, I can ask a few quick questions (warm or cool tones? bright or muted?).\n- Or you can just tell me your favourite colour and I’ll remember it for our chat.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1162, 'prompt_tokens': 11, 'total_tokens': 1173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1088, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D3y8fdQWIP0CzHPyRt7QVqemA5bqi', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c1298-bebe-7051-9746-5efc4d815fed-0', usage_metadata={'input_tokens': 11, 'output_tokens': 1162, 'total_tokens': 1173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1088}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "gpt-5-nano",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='8882055f-e67f-4a73-a2d3-de8ae2254fb1'),
#               AIMessage(content='Hi Seán! Nice to meet you. Green is a great color—fresh and natural. What would you like to chat about today? I can suggest green-themed ideas (outfits, decor, palettes), share fun facts about the color, or talk about something you enjoy.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 577, 'prompt_tokens': 18, 'total_tokens': 595, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D3y9vbH3O8iD0YMFiBEIszsxG9pUo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c1299-ee16-79c2-a537-2c94745b2916-0', usage_metadata={'input_tokens': 18, 'output_tokens': 577, 'total_tokens': 595, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='8882055f-e67f-4a73-a2d3-de8ae2254fb1'),
#               AIMessage(content='Hi Seán! Nice to meet you. Green is a great color—fresh and natural. What would you like to chat about today? I can suggest green-themed ideas (outfits, decor, palettes), share fun facts about the color, or talk about something you enjoy.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 577, 'prompt_tokens': 18, 'total_tokens': 595, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D3y9vbH3O8iD0YMFiBEIszsxG9pUo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c1299-ee16-79c2-a537-2c94745b2916-0', usage_metadata={'input_tokens': 18, 'output_tokens': 577, 'total_tokens': 595, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='734b97a3-f128-4b51-ab1e-76f810894c96'),
#               AIMessage(content='Your favourite colour is green. Want some green-themed ideas or fun facts about green?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 218, 'prompt_tokens': 89, 'total_tokens': 307, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D3yBP2GPm3OTNdG04jzZAf84haPEu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c129b-5455-7be0-bab0-8703361c2a83-0', usage_metadata={'input_tokens': 89, 'output_tokens': 218, 'total_tokens': 307, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})]}
