# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]},
    config
)

print(response['messages'][-1].content)
# Out:
# Nice! Leftover chicken and rice are a perfect base for many quick meals. Here are tasty options you can make with what you have, plus a note on what extra basics you might want to grab if you have them.
#
# 1) Chicken Fried Rice (one-pan)
# - Why it works: Reuses both leftovers in a single pan; adds a few veggies and soy for flavor.
# - What you might add: eggs, peas/carrots, green onions, soy sauce, a splash of sesame oil.
# - Time: about 15–20 minutes.
#
# 2) Creamy Chicken and Rice Skillet
# - Why it works: A cozy one-pan dish using leftover chicken and rice with a creamy sauce and cheese.
# - What you might add: cream or milk, a little chicken stock, cheddar/ parmesan.
# - Time: about 25–30 minutes.
#
# 3) Cheesy Chicken and Rice Casserole
# - Why it works: Bakes into a comforting casserole; great for easy leftovers you already have.
# - What you might add: cream of chicken/mushroom soup or a homemade roux, plus a bit of cheese on top.
# - Time: about 30–40 minutes (plus bake time).
#
# 4) Chicken Rice Enchilada Casserole
# - Why it works: A family-friendly, cheesy casserole with a simple enchilada sauce twist.
# - What you might add: enchilada sauce, black beans or corn, more cheese.
# - Time: about 35–45 minutes.
#
# 5) Rotisserie/Leftover Chicken and Rice Skillet
# - Why it works: Great for using any pre-cooked chicken; quick to pull together.
# - What you might add: a couple veggies (peppers, peas), a flavorful sauce (soy, lemon, or a creamy sauce).
# - Time: about 25–30 minutes.
#
# 6) One-Pot Chicken and Rice (classic skillet)
# - Why it works: A traditional, comforting one-pot meal; easy to customize with pantry basics.
# - What you might add: broth, herbs, some vegetables like mushrooms or spinach.
# - Time: about 30–40 minutes.
#
# 7) Creamy Chicken and Rice Soup (lighter or creamy version)
# - Why it works: Turn leftovers into a nourishing soup; great for a lighter dinner.
# - What you might add: chicken broth, milk or cream, garlic, onion, veggies.
# - Time: about 25–30 minutes.
#
# Want the full recipe steps for any of these? Tell me which one you’d like, and I’ll pull a complete recipe with ingredients and step-by-step instructions. If you have any dietary preferences (lower fat, dairy-free, gluten-free) or extra ingredients you want to use up (vegetables, cheese types, canned soup, etc.), I can tailor a plan to fit.

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='be0360b5-55da-4714-ae8d-4628bd103965'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 741, 'prompt_tokens': 199, 'total_tokens': 940, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D4H6GzCtLVWCdNPEJiERKx6UBKDWN', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c16f0-f4a2-7d01-9c60-76dbd3d3d7c7-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'leftover chicken and rice recipes'}, 'id': 'call_J2cPaof4glZJPePQCrS09VI8', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken fried rice recipe using leftover chicken and rice'}, 'id': 'call_CypZqC3SU6Nh72g9FOlI63BE', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'one pot chicken and rice bake recipe using leftovers'}, 'id': 'call_UXFJbrs2CWBmZZrYIpuvNvcy', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken and rice soup recipe leftover chicken and rice'}, 'id': 'call_bEpkehny7D5ox3HBhwuJG9Id', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken and rice casserole recipe leftover chicken'}, 'id': 'call_Y7tktbZ9cnZ9bDOlWyHOQQy1', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'recipes using leftover chicken and leftover rice'}, 'id': 'call_w9RCQ9469bTZqy3f9h75aZEm', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'leftover rice and chicken stir fry recipe'}, 'id': 'call_y0Ay7M4qcDWG8bSwT8DE9aw1', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'rice and chicken skillet recipe'}, 'id': 'call_GFU4XjJmbW6WFS7HUhWNieke', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'pantry-friendly chicken and rice recipe'}, 'id': 'call_RmURMlBLzbhJvefTa1tKF3q9', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'easy chicken and rice recipe with leftovers'}, 'id': 'call_5BI7SNePu5FN0UQFwEUWFu8F', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'how to use leftover chicken and rice'}, 'id': 'call_MBOhMnA0wlHksZSwYhznQd9E', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'fast chicken and rice dinner from leftovers'}, 'id': 'call_tkN1h0WV6omBgUj7gBn1WwDW', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'creamy chicken and rice soup from leftovers'}, 'id': 'call_z076WBEoPC3frEkT4f78hkhS', 'type': 'tool_call'}], usage_metadata={'input_tokens': 199, 'output_tokens': 741, 'total_tokens': 940, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#               ToolMessage(content='{"query": "leftover chicken and rice recipes", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/2612842568992672/posts/3368384463438475/", "title": "Leftover chicken and rice casserole ideas needed - Facebook", "content": "Dice the leftover chicken while boiling the rice. Put a cup of milk in a saucepan and add a can of cream of chicken soup. As milk/soup mixture", "score": 0.99990463, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "Leftover Chicken and Rice Recipe For Dinner\\nTracy\'s Cookin’\\n14700 subscribers\\n56 likes\\n8401 views\\n6 May 2022\\nThis Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy Dinner Recipe using leftover food.\\n4 comments\\n", "score": 0.99989367, "raw_content": null}, {"url": "https://www.facebook.com/TheRecipeCritic/posts/grab-you-leftover-rice-and-chicken-toss-it-all-in-a-pan-and-boom-dinner-is-ready/1251345426337809/", "title": "Grab you leftover rice and chicken, toss it all in a pan, and boom ...", "content": "Recipe Ingredients: 2 cups cooked and chilled rice 1 lb chicken breast, cut into small pieces 2 tablespoons vegetable oil 1 small onion", "score": 0.99984765, "raw_content": null}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - The Best Easy Dinner Recipes", "content": "Simple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.", "score": 0.9997428, "raw_content": null}, {"url": "https://www.crazyforcrust.com/chicken-and-rice-casserole/", "title": "EASY Chicken and Rice Casserole - Crazy for Crust", "content": "Use leftover chicken or turkey and rice to make this cheesy chicken casserole recipe! Recipe Video. Prep Time 10 minutes minutes. Cook Time 25", "score": 0.99973255, "raw_content": null}], "response_time": 0.85, "request_id": "7a8d66a1-690b-4238-8596-0b9c38885e20"}', name='web_search', id='466c0f55-17af-47a4-bf1a-c18309658dfa', tool_call_id='call_J2cPaof4glZJPePQCrS09VI8'),
#               ToolMessage(content='{"query": "chicken fried rice recipe using leftover chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/", "title": "Leftover Chicken and Egg Fried Rice", "content": "Ingredients · 2 tablespoons olive, rapeseed or coconut oil · 300-500 g leftover chicken shredded · 500 g pre-cooked brown rice · 100 g frozen peas · 100 g frozen", "score": 0.8865877, "raw_content": null}, {"url": "https://therecipecritic.com/chicken-fried-rice/", "title": "Better than Takeout Chicken Fried Rice", "content": "This easy chicken fried rice uses leftover rice, chicken, and veggies for a fast, flavorful one-pan dinner the whole family will love.", "score": 0.88372874, "raw_content": null}, {"url": "https://www.allrecipes.com/easy-chicken-fried-rice-recipe-8644579", "title": "Easy Chicken Fried Rice Recipe", "content": "This is a quick and easy recipe for chicken fried rice that I make when I have leftover roast chicken and cooked rice.", "score": 0.8732259, "raw_content": null}, {"url": "https://streetsmartnutrition.com/easy-weeknight-fried-rice/", "title": "Rotisserie Chicken Fried Rice For An Easy Weeknight Meal", "content": "This Rotisserie Chicken Fried Rice recipe uses, you guessed it, leftover rotisserie chicken with white rice, veggies, and plenty of seasoning!", "score": 0.87139857, "raw_content": null}, {"url": "https://www.simplyrecipes.com/recipes/chicken_fried_rice/", "title": "Chicken Fried Rice Recipe (Better Than Take-Out!)", "content": "Fried rice is best made with leftover rice that\'s at least a day old. Otherwise it becomes gummy in the skillet. If you don\'t have any leftover rice from the", "score": 0.8338803, "raw_content": null}], "response_time": 0.93, "request_id": "34cb9d65-c45f-4f3f-a702-bdb1afd228dd"}', name='web_search', id='25882323-aa6c-4b37-83da-4ae9cde39c80', tool_call_id='call_CypZqC3SU6Nh72g9FOlI63BE'),
#               ToolMessage(content='{"query": "one pot chicken and rice bake recipe using leftovers", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://onedadskitchen.com/2014/10/07/got-leftovers-make-this-chicken-and-rice-casserole-with-lemon-and-parmesan/", "title": "Got Leftovers? Make This Chicken and Rice Casserole with Lemon ...", "content": "This recipe makes great use of all kinds of leftovers and comes together nicely to form a one pot dish filled with chicken, rice and vegetables.", "score": 0.83452857, "raw_content": null}, {"url": "https://www.facebook.com/groups/2612842568992672/posts/3368384463438475/", "title": "Leftover chicken and rice casserole ideas needed - Facebook", "content": "Grease a 1 1/2 quart shallow baking dish. Spread rice in prepared baking dish, sprinkle with the peas and then pour creamed chicken mixture over", "score": 0.7636429, "raw_content": null}, {"url": "https://www.crazyforcrust.com/chicken-and-rice-casserole/", "title": "EASY Chicken and Rice Casserole - Crazy for Crust", "content": "Use leftover chicken or turkey and rice to make this cheesy chicken casserole recipe! Recipe Video. Prep Time 10 minutes minutes. Cook Time 25", "score": 0.69399214, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=mAjV92vcVgY", "title": "Recipe: Left-over Chicken and Rice Casserole (CLOVER) - YouTube", "content": "... left overs will be had so why not transform it into another meal. Our Classic Left over chicken and rice casserole is one of those budget", "score": 0.6844544, "raw_content": null}, {"url": "https://iowagirleats.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice - Family Favorite Recipe - Iowa Girl Eats", "content": "This recipe makes a ton, but leftovers heat up very well for lunch or dinner the next day. It\'s family-friendly. I have three little kids so", "score": 0.6760432, "raw_content": null}], "response_time": 0.98, "request_id": "98436bf8-de73-4ce7-801f-1ffef62e464a"}', name='web_search', id='a7ff0721-a3cf-41b0-9c1d-5f54b4a5f4a8', tool_call_id='call_UXFJbrs2CWBmZZrYIpuvNvcy'),
#               ToolMessage(content='{"query": "chicken and rice soup recipe leftover chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/cheapmealideas/posts/7250479938344445/", "title": "Creamy chicken rice soup recipe with leftover rice - Facebook", "content": "Made some creamy chicken rice soup. About 2 cups of leftover rice, 1 can of cream of chicken soup,I cup of chicken broth. About a tablespoon of lemon pepper.", "score": 0.8690161, "raw_content": null}, {"url": "https://www.facebook.com/groups/cheapmealideas/posts/3627546487304493/", "title": "Leftover chicken and rice soup recipe - Facebook", "content": "Add onion, garlic, carrots, and celery. Cook for 5 minutes, stirring now and then. Add rice, chicken broth, thyme, and parsley. Bring everything", "score": 0.8539252, "raw_content": null}, {"url": "https://entertainingwithbeth.com/easy-chicken-and-rice-soup/", "title": "Easy Chicken and Rice Soup - Entertaining with Beth", "content": "Made with store-bought rotisserie chicken, or leftover chicken, and microwavable rice this is a delicious 15-minute meal!", "score": 0.85097736, "raw_content": null}, {"url": "https://iowagirleats.com/easy-chicken-and-rice-soup/", "title": "Easy Chicken and Rice Soup - Quick and Comforting - Iowa Girl Eats", "content": "Scoop leftover chicken and rice soup into individual-sized storage containers then store in the refrigerator for 3-4 days. Reheat in the microwave with an extra", "score": 0.8312667, "raw_content": null}, {"url": "https://www.landolakes.com/recipe/9681/super-easy-chicken-rice-soup/", "title": "Super Easy Chicken & Rice Soup Recipe | Land O\'Lakes", "content": "Use leftover rice and purchase a rotisserie chicken to make this simple and satisfying soup. Super Easy Chicken & Rice Soup 4.8 out of 5 stars.", "score": 0.82391036, "raw_content": null}], "response_time": 0.93, "request_id": "3650605b-8bed-4f7c-9076-db93b19ca171"}', name='web_search', id='6ce70ff3-9b76-42de-8537-d2513a299890', tool_call_id='call_bEpkehny7D5ox3HBhwuJG9Id'),
#               ToolMessage(content='{"query": "chicken and rice casserole recipe leftover chicken", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://therealfooddietitians.com/cheesy-chicken-and-rice-casserole-recipe/", "title": "Cheesy Chicken and Rice Casserole - The Real Food Dietitians", "content": "Great use of leftovers: I make this healthy chicken recipe when I have leftover cooked rice or leftover shredded or chopped chicken to use up.", "score": 0.9999596, "raw_content": null}, {"url": "https://www.cleverlysimple.com/chicken-and-rice-casserole/", "title": "Chicken and Rice Casserole - Cleverly Simple", "content": "This oven-baked chicken and rice casserole is a family favorite! Using fully cooked or leftover chicken, create a creamy and delicious 9×13 pan dinner", "score": 0.99995315, "raw_content": null}, {"url": "https://www.crazyforcrust.com/chicken-and-rice-casserole/", "title": "EASY Chicken and Rice Casserole - Crazy for Crust", "content": "Use leftover chicken or turkey and rice to make this cheesy chicken casserole recipe! Recipe Video. Prep Time 10 minutes minutes. Cook Time 25", "score": 0.9999517, "raw_content": null}, {"url": "https://www.facebook.com/groups/2612842568992672/posts/3368384463438475/", "title": "Leftover chicken and rice casserole ideas needed - Facebook", "content": "INGREDIENTS 4 tablespoons butter, divided 3 tablespoons flour 1 teaspoon dried thyme 1 cup chicken broth 1 cup milk 2 cups diced cooked chicken", "score": 0.99987066, "raw_content": null}, {"url": "https://www.thecountrycook.net/chicken-and-rice-casserole/", "title": "Chicken and Rice Casserole - The Country Cook", "content": "This Chicken and Rice Casserole is a blast from the past. Rotisserie chicken in a creamy, rice filling topped with bread crumbs! A family favorite meal!", "score": 0.9995197, "raw_content": null}], "response_time": 0.82, "request_id": "cf71cef3-262d-4b96-871a-9096a845fb6c"}', name='web_search', id='e9aaaecd-4436-449b-9200-77da834efed9', tool_call_id='call_Y7tktbZ9cnZ9bDOlWyHOQQy1'),
#               ToolMessage(content='{"query": "recipes using leftover chicken and leftover rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/2612842568992672/posts/3368384463438475/", "title": "Leftover chicken and rice casserole ideas needed - Facebook", "content": "Add fresh chopped herbs, some salt and pepper, chicken, chopped leftover veggies and rice, and stir together. ○ Add enough chicken stock to", "score": 0.85538095, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "Leftover Chicken and Rice Recipe For Dinner\\nTracy\'s Cookin’\\n14700 subscribers\\n56 likes\\n8401 views\\n6 May 2022\\nThis Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy Dinner Recipe using leftover food.\\n4 comments\\n", "score": 0.85509074, "raw_content": null}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - The Best Easy Dinner Recipes", "content": "Simple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.", "score": 0.8335554, "raw_content": null}, {"url": "https://www.crazyforcrust.com/chicken-and-rice-casserole/", "title": "EASY Chicken and Rice Casserole - Crazy for Crust", "content": "Use leftover chicken or turkey and rice to make this cheesy chicken casserole recipe! Recipe Video. Prep Time 10 minutes minutes. Cook Time 25", "score": 0.81665546, "raw_content": null}, {"url": "https://www.reddit.com/r/recipes/comments/4dsvy6/what_can_i_make_with_already_cooked_chicken_and/", "title": "What can I make with already cooked chicken and rice? - Reddit", "content": "Make a pilaf. You can use rice or 1/2 rice and 1/2 bulgur. Chop a small onion, a carrot and a couple cloves of garlic and fry in olive oil until the onion is", "score": 0.8010817, "raw_content": null}], "response_time": 0.79, "request_id": "99422c82-a8e6-4251-b85a-5c94ca825950"}', name='web_search', id='e7b77305-13b7-4236-949d-45745a6e5b78', tool_call_id='call_w9RCQ9469bTZqy3f9h75aZEm'),
#               ToolMessage(content='{"query": "leftover rice and chicken stir fry recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/cheapmealideas/posts/4141925485866588/", "title": "Leftover rice and chicken stir-fry recipe", "content": "Ingredients: - 1 cup (200g) cooked chicken breast, diced - 2 cups (250g) cooked long-grain rice, day-old is best - 1/2 cup (75g) frozen peas - 2", "score": 0.99996114, "raw_content": null}, {"url": "https://www.jocooks.com/recipes/chicken-fried-rice/", "title": "Chicken Fried Rice", "content": "Better than takeout and done in 30 minutes! This easy Chicken Fried Rice is the ultimate way to use up leftover rice.", "score": 0.99939764, "raw_content": null}, {"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/", "title": "Leftover Chicken and Egg Fried Rice", "content": "Ingredients ; 2 tablespoons olive, rapeseed or coconut oil ; 300-500 g leftover chicken shredded ; 500 g pre-cooked brown rice ; 100 g frozen peas ; 100 g frozen", "score": 0.9992848, "raw_content": null}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - The Best Easy Dinner Recipes", "content": "Simple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.", "score": 0.9986749, "raw_content": null}, {"url": "https://streetsmartnutrition.com/easy-weeknight-fried-rice/", "title": "Rotisserie Chicken Fried Rice For An Easy Weeknight Meal", "content": "This Rotisserie Chicken Fried Rice recipe uses, you guessed it, leftover rotisserie chicken with white rice, veggies, and plenty of seasoning!", "score": 0.99824536, "raw_content": null}], "response_time": 1.07, "request_id": "e403ab9f-c821-4b17-9cb6-001fc6e0436a"}', name='web_search', id='ce41d69a-6dff-4f35-82e6-7eac2035ab6b', tool_call_id='call_y0Ay7M4qcDWG8bSwT8DE9aw1'),
#               ToolMessage(content='{"query": "rice and chicken skillet recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.simplyrecipes.com/recipes/skillet_chicken_and_rice/", "title": "Skillet Chicken and Rice - Simply Recipes", "content": "Skillet chicken and rice is a classic one-pot meal, perfect for a weeknight and totally kid-friendly. Serve it on its own or with a salad, and dinner is done!", "score": 0.9997565, "raw_content": null}, {"url": "https://www.campbells.com/recipes/skillet-cheesy-chicken-rice/", "title": "Skillet Cheesy Chicken & Rice - Recipes - Campbells.com", "content": "Stir the soup, water, onion powder, black pepper and rice in the skillet and heat to a boil. Reduce the heat to low. Cover and cook for 15 minutes, stirring", "score": 0.9997367, "raw_content": null}, {"url": "https://www.budgetbytes.com/creamy-chicken-and-rice-skillet/", "title": "Creamy Chicken and Rice Skillet - Budget Bytes", "content": "This easy one pot Creamy Chicken and Rice Skillet makes a comforting weeknight dinner during those long, dark winter months! Makes great leftovers, too!", "score": 0.99964297, "raw_content": null}, {"url": "https://www.fromvalerieskitchen.com/tex-mex-chicken-rice-skillet/", "title": "Tex-Mex Chicken and Rice Skillet (One Pot) | Valerie\'s Kitchen", "content": "This cheesy one pot Tex-Mex Chicken and Rice Skillet is loaded with corn, peppers, and black beans for a delicious meal in 30 minutes!", "score": 0.99948066, "raw_content": null}, {"url": "https://thedefineddish.com/chicken-and-rice-taco-skillet/", "title": "Chicken and Rice Taco Skillet - The Defined Dish", "content": "Step One: Preheat the oven · Step Two: Season the Chicken · Step Three: Brown the Chicken · Step Four: Cook the Veggies · Step Five: Toast the Rice.", "score": 0.9992563, "raw_content": null}], "response_time": 0.58, "request_id": "def6ab1e-f86c-4499-b3e2-2c70a4794354"}', name='web_search', id='037c2821-6ff2-4ce7-b5be-6ef9298fa0b5', tool_call_id='call_GFU4XjJmbW6WFS7HUhWNieke'),
#               ToolMessage(content='{"query": "pantry-friendly chicken and rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Irresistible Chicken and Rice Recipe Ready in 35 Minutes", "url": "https://catchymeals.com/easy-chicken-and-rice-recipe/", "content": "Why You’ll Love This Chicken and Rice Recipe . This dish is a winner for so many reasons—here’s why it’s become a staple in my kitchen: One-pot wonder: Less cleanup means more time to relax (or sneak seconds). Pantry - friendly : No fancy ingredients—just simple", "score": 0.9999584, "raw_content": null}, {"title": "Pantry Dinner - OAMC - Chicken and Rice Recipe", "url": "https://eathealthy365.com/the-ultimate-freezer-friendly-chicken-and-rice-bake/", "content": "Secrets to the Perfect Freezer- Friendly Chicken and Rice . Nutrition Facts (per serving). Frequently Asked Questions. Can I use brown rice in this chicken and rice recipe ? What other vegetables can I add to this pantry dinner?", "score": 0.9999478, "raw_content": null}, {"title": "Smothered Chicken And Rice Recipe - cookingwithjessica.com", "url": "https://cookingwithjessica.com/smothered-chicken-and-rice-recipe/", "content": "The magic of Smothered Chicken and Rice lies in its simple, pantry - friendly ingredients. Each one plays an essential role in creating this cozy masterpiece. Chicken thighs or breasts: Bone-in, skin-on chicken thighs are ideal for this recipe , as they stay juicy and flavorful.", "score": 0.9999435, "raw_content": null}, {"title": "Juicy Honey BBQ Chicken Rice Recipe in Just... - www.dinnernest.com", "url": "https://www.dinnernest.com/honey-bbq-chicken-rice-recipe/", "content": "Pantry - friendly : Uses ingredients I always have on hand—no fancy grocery runs needed. Customizable: Spice it up, swap the rice , or pile on veggies—it’s endlessly adaptable.Honey BBQ Chicken Rice Variations. Oh, this recipe is practically begging to be customized!", "score": 0.99988854, "raw_content": null}, {"title": "Delicious 30-Minute Honey BBQ Chicken and Rice Recipe", "url": "https://recipesbycharlotte.com/honey-bbq-chicken-and-rice/", "content": "Jump to Recipe ·Print Recipe . Honey BBQ Chicken and Rice saves my sanity on frantic weeknights. Pantry - friendly : No fancy ingredients here. I bet you’ve got most of this stuff in your kitchen right now. Adaptable: Swap in whatever veggies you’ve got lurking in the freezer.", "score": 0.99979657, "raw_content": null}], "response_time": 3.65, "request_id": "95841970-a5b8-4788-9c58-cf70fcf36574"}', name='web_search', id='7418c63f-aacd-47cb-9083-eed1eb795a07', tool_call_id='call_RmURMlBLzbhJvefTa1tKF3q9'),
#               ToolMessage(content='{"query": "easy chicken and rice recipe with leftovers", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.crazyforcrust.com/chicken-and-rice-casserole/", "title": "EASY Chicken and Rice Casserole - Crazy for Crust", "content": "It\'s so easy you can make it on a weeknight! It\'s ... Use leftover chicken or turkey and rice to make this cheesy chicken casserole recipe!", "score": 0.99992275, "raw_content": null}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - The Best Easy Dinner Recipes", "content": "Simple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.", "score": 0.99991584, "raw_content": null}, {"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/", "title": "Leftover Chicken and Egg Fried Rice - Easy Peasy Foodie", "content": "Ingredients · 2 tablespoons olive, rapeseed or coconut oil · 300-500 g leftover chicken shredded · 500 g pre-cooked brown rice · 100 g frozen peas · 100 g frozen", "score": 0.999884, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "Leftover Chicken and Rice Recipe For Dinner\\nTracy\'s Cookin’\\n14700 subscribers\\n56 likes\\n8401 views\\n6 May 2022\\nThis Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy Dinner Recipe using leftover food.\\n4 comments\\n", "score": 0.9998634, "raw_content": null}, {"url": "https://www.allrecipes.com/recipe/233983/mamaws-chicken-and-rice-casserole/", "title": "Mamaw\'s Chicken and Rice Casserole Recipe - Allrecipes", "content": "Quick and easy for school nights, and the leftovers are just as good! You can use less butter on top of course, my Momma and Mamaw always", "score": 0.9998313, "raw_content": null}], "response_time": 0.73, "request_id": "89551bfc-7a0e-4c44-b687-9e40d080c81f"}', name='web_search', id='d1a8c67c-3205-40e7-8bbf-d5d4755cbe2e', tool_call_id='call_5BI7SNePu5FN0UQFwEUWFu8F'),
#               ToolMessage(content='{"query": "how to use leftover chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - The Best Easy Dinner Recipes", "content": "Simple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.", "score": 0.99993443, "raw_content": null}, {"url": "https://www.facebook.com/groups/2612842568992672/posts/3368384463438475/", "title": "Leftover chicken and rice casserole ideas needed", "content": "Gradually stir in broth and milk, stirring until thick and smooth. Stir in chicken and add salt and pepper; set aside. Grease a 1 1/2 quart", "score": 0.9998591, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "Leftover Chicken and Rice Recipe For Dinner\\nTracy\'s Cookin’\\n14700 subscribers\\n56 likes\\n8401 views\\n6 May 2022\\nThis Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy Dinner Recipe using leftover food.\\n4 comments\\n", "score": 0.99984646, "raw_content": null}, {"url": "https://www.facebook.com/groups/cheapmealideas/posts/7907950385930727/", "title": "What are some recipe ideas using leftover rice and chicken?", "content": "Shred the chicken then add the cooked rice. Next, sauté onions and baby sweet or bell peppers until done. You may use your favorite type of", "score": 0.999826, "raw_content": null}, {"url": "https://www.thechunkychef.com/chicken-rice-enchilada-casserole/", "title": "Chicken and Rice Enchilada Casserole", "content": "This cheesy, savory, and easy chicken enchilada casserole uses leftover chicken, and is ready in just 35 minutes! It\'s completely customize-able too!", "score": 0.9997868, "raw_content": null}], "response_time": 0.8, "request_id": "bc5c5b38-20ff-4156-8c6c-82646dde5f75"}', name='web_search', id='b123d8df-dcfb-4463-a0a5-5663a7375dfc', tool_call_id='call_MBOhMnA0wlHksZSwYhznQd9E'),
#               ToolMessage(content='{"query": "fast chicken and rice dinner from leftovers", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - The Best Easy Dinner Recipes", "content": "Simple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.", "score": 0.99973255, "raw_content": null}, {"url": "https://www.crazyforcrust.com/chicken-and-rice-casserole/", "title": "EASY Chicken and Rice Casserole - Crazy for Crust", "content": "Easy Chicken and Rice Casserole is an fast comfort food dinner. Use leftover chicken or turkey and rice to make this cheesy chicken", "score": 0.9997284, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "Leftover Chicken and Rice Recipe For Dinner\\nTracy\'s Cookin’\\n14700 subscribers\\n56 likes\\n8401 views\\n6 May 2022\\nThis Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy Dinner Recipe using leftover food.\\n4 comments\\n", "score": 0.9997086, "raw_content": null}, {"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/", "title": "Leftover Chicken and Egg Fried Rice - Easy Peasy Foodie", "content": "Ingredients ; 2 tablespoons olive, rapeseed or coconut oil ; 300-500 g leftover chicken shredded ; 500 g pre-cooked brown rice ; 100 g frozen peas ; 100 g frozen", "score": 0.9992387, "raw_content": null}, {"url": "https://www.laurafuentes.com/rotisserie-chicken-and-rice/", "title": "Rotisserie Chicken and Rice: Easy 30 minute dinner recipe", "content": "Make this rotisserie chicken and rice recipe with as much or as little meat as you\'ve got, plus those frozen vegetables that always save the day!", "score": 0.99918956, "raw_content": null}], "response_time": 0.83, "request_id": "e1848f9e-0cc8-44c6-899f-8aada57fbb7f"}', name='web_search', id='c0ac10f7-d13d-4d81-94b7-6daa7f8836cd', tool_call_id='call_tkN1h0WV6omBgUj7gBn1WwDW'),
#               ToolMessage(content='{"query": "creamy chicken and rice soup from leftovers", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/cheapmealideas/posts/7250479938344445/", "title": "Creamy chicken rice soup recipe with leftover rice - Facebook", "content": "Made some creamy chicken rice soup. About 2 cups of leftover rice, 1 can of cream of chicken soup,I cup of chicken broth. About a tablespoon of lemon pepper.", "score": 0.89302075, "raw_content": null}, {"url": "https://www.thekitchn.com/creamy-chicken-rice-soup-recipe-23024695", "title": "30-Minute Creamy Chicken and Rice Soup - The Kitchn", "content": "This soup leans on both leftover rice and leftover cooked, shredded chicken, it comes together in less than 30 minutes.", "score": 0.85797083, "raw_content": null}, {"url": "https://www.saltandlavender.com/creamy-chicken-rice-soup/", "title": "Creamy Chicken and Rice Soup - Salt & Lavender", "content": "Leftover chicken and rice soup can be stored in an airtight container in the fridge for 3-4 days. · Reheat this chicken soup in a saucepan over a", "score": 0.8361405, "raw_content": null}, {"url": "https://www.budgetbytes.com/creamy-chicken-rice-soup/", "title": "Creamy Chicken and Rice Soup - Budget Bytes", "content": "Keep leftovers of this chicken and rice soup in the fridge for up to 3-4 days. Reheat on the stove or in the microwave, adding a splash of broth", "score": 0.82254606, "raw_content": null}, {"url": "https://www.facebook.com/RecipeGirl/posts/recipe-httpswwwrecipegirlcomcreamy-chicken-and-rice-souplove-to-make-this-and-ea/937854307695948/", "title": "RecipeGirl - Creamy Chicken and Rice Soup", "content": "This soup makes great leftovers but you might want to thin it slightly with skim milk or water when reheating. ... Bring just to boiling, then", "score": 0.7917732, "raw_content": null}], "response_time": 0.8, "request_id": "28ad1fbf-d08d-4ff9-89ce-9cd2fc66159f"}', name='web_search', id='6de0e574-aaa2-48b3-b752-ac97cb5feab5', tool_call_id='call_z076WBEoPC3frEkT4f78hkhS'),
#               AIMessage(content='Nice! Leftover chicken and rice are a perfect base for many quick meals. Here are tasty options you can make with what you have, plus a note on what extra basics you might want to grab if you have them.\n\n1) Chicken Fried Rice (one-pan)\n- Why it works: Reuses both leftovers in a single pan; adds a few veggies and soy for flavor.\n- What you might add: eggs, peas/carrots, green onions, soy sauce, a splash of sesame oil.\n- Time: about 15–20 minutes.\n\n2) Creamy Chicken and Rice Skillet\n- Why it works: A cozy one-pan dish using leftover chicken and rice with a creamy sauce and cheese.\n- What you might add: cream or milk, a little chicken stock, cheddar/ parmesan.\n- Time: about 25–30 minutes.\n\n3) Cheesy Chicken and Rice Casserole\n- Why it works: Bakes into a comforting casserole; great for easy leftovers you already have.\n- What you might add: cream of chicken/mushroom soup or a homemade roux, plus a bit of cheese on top.\n- Time: about 30–40 minutes (plus bake time).\n\n4) Chicken Rice Enchilada Casserole\n- Why it works: A family-friendly, cheesy casserole with a simple enchilada sauce twist.\n- What you might add: enchilada sauce, black beans or corn, more cheese.\n- Time: about 35–45 minutes.\n\n5) Rotisserie/Leftover Chicken and Rice Skillet\n- Why it works: Great for using any pre-cooked chicken; quick to pull together.\n- What you might add: a couple veggies (peppers, peas), a flavorful sauce (soy, lemon, or a creamy sauce).\n- Time: about 25–30 minutes.\n\n6) One-Pot Chicken and Rice (classic skillet)\n- Why it works: A traditional, comforting one-pot meal; easy to customize with pantry basics.\n- What you might add: broth, herbs, some vegetables like mushrooms or spinach.\n- Time: about 30–40 minutes.\n\n7) Creamy Chicken and Rice Soup (lighter or creamy version)\n- Why it works: Turn leftovers into a nourishing soup; great for a lighter dinner.\n- What you might add: chicken broth, milk or cream, garlic, onion, veggies.\n- Time: about 25–30 minutes.\n\nWant the full recipe steps for any of these? Tell me which one you’d like, and I’ll pull a complete recipe with ingredients and step-by-step instructions. If you have any dietary preferences (lower fat, dairy-free, gluten-free) or extra ingredients you want to use up (vegetables, cheese types, canned soup, etc.), I can tailor a plan to fit.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2629, 'prompt_tokens': 7777, 'total_tokens': 10406, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 2048, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D4H6VicinrAmVuqLy6WBa1qGLFPBz', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c16f1-3119-79b1-a1f2-bddd45ba095f-0', usage_metadata={'input_tokens': 7777, 'output_tokens': 2629, 'total_tokens': 10406, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 2048}})]}
